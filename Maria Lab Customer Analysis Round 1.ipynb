# %%
import os
os.chdir(r'C:\Users\Mimzd\Desktop\lab')

# %%
import csv

# %%
import pandas as pd

# %%
dataset1 = pd.read_csv( 'file1.csv' )
dataset1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
dataset2 = pd.read_csv( 'file2.csv' )
dataset2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
dataset3 = pd.read_csv( 'file3.csv' )
dataset3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print (dataset1.shape)
# Out:
# (4008, 11)

# %%
print (dataset2.shape)
# Out:
# (996, 11)

# %%
print (dataset3.shape)
# Out:
# (7070, 11)

# %%
dataset1 = dataset1.rename(columns ={ 'ST' : 'State' })

# %%
dataset2 = dataset2.rename(columns ={ 'ST' : 'State' })

# %%
dataset3 = dataset3.rename(columns ={ 'Gender' : 'GENDER'})

# %%
dataset1
#the dataset1 'ST' got stuck to a joke i made...turns out my wi-fi stopped working and it was not stuck after all haha
# Out:
#      Customer       State GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
dataset2
# Out:
#     Customer       State GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
dataset3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# Rearrange the columns in the dataframe as needed

# %%
dataset1 = dataset1[['Customer' , 'Income' , 'Monthly Premium Auto' , 'Number of Open Complaints' , 'State' , 'Policy Type' , 'Vehicle Class' , 'Total Claim Amount' , 'GENDER' , 'Education', 'Customer Lifetime Value']]
dataset1
#I got so happy when it worked because for 20mins i couldn't understand what was the problem, it was that i didn't see the name was 'Total Claim Amount' and not 'Total'
# Out:
#      Customer   Income  Monthly Premium Auto Number of Open Complaints  \
# 0     RB50392      0.0                1000.0                    1/0/00
# 1     QZ44356      0.0                  94.0                    1/0/00
# 2     AI49188  48767.0                 108.0                    1/0/00
# 3     WW63253      0.0                 106.0                    1/0/00
# 4     GA49547  36357.0                  68.0                    1/0/00
# ...       ...      ...                   ...                       ...
# 4003      NaN      NaN                   NaN                       NaN
# 4004      NaN      NaN                   NaN                       NaN
# 4005      NaN      NaN                   NaN                       NaN
# 4006      NaN      NaN                   NaN                       NaN
# 4007      NaN      NaN                   NaN                       NaN
#
#            State     Policy Type  Vehicle Class  Total Claim Amount GENDER  \
# ...

# %%
dataset2 = dataset2[['Customer' , 'Income' , 'Monthly Premium Auto' , 'Number of Open Complaints' , 'State' , 'Policy Type' , 'Vehicle Class' , 'Total Claim Amount' , 'GENDER' , 'Education', 'Customer Lifetime Value']]
dataset2
# Out:
#     Customer  Income  Monthly Premium Auto Number of Open Complaints  \
# 0    GS98873   16061                    88                    1/0/00
# 1    CW49887   79487                   114                    1/0/00
# 2    MY31220   54230                   112                    1/0/00
# 3    UH35128   71210                   214                    1/1/00
# 4    WH52799   94903                    94                    1/0/00
# ..       ...     ...                   ...                       ...
# 991  HV85198   63513                    70                    1/0/00
# 992  BS91566   58161                    68                    1/0/00
# 993  IL40123   83640                    70                    1/0/00
# 994  MY32149       0                    96                    1/0/00
# 995  SA91515       0                   111                    1/0/00
#
#           State     Policy Type  Vehicle Class  Total Claim Amount GENDER  \
# ...

# %%
dataset3 = dataset2[['Customer' , 'Income' , 'Monthly Premium Auto' , 'Number of Open Complaints' , 'State' , 'Policy Type' , 'Vehicle Class' , 'Total Claim Amount' , 'GENDER' , 'Education', 'Customer Lifetime Value']]
dataset3
# Out:
#     Customer  Income  Monthly Premium Auto Number of Open Complaints  \
# 0    GS98873   16061                    88                    1/0/00
# 1    CW49887   79487                   114                    1/0/00
# 2    MY31220   54230                   112                    1/0/00
# 3    UH35128   71210                   214                    1/1/00
# 4    WH52799   94903                    94                    1/0/00
# ..       ...     ...                   ...                       ...
# 991  HV85198   63513                    70                    1/0/00
# 992  BS91566   58161                    68                    1/0/00
# 993  IL40123   83640                    70                    1/0/00
# 994  MY32149       0                    96                    1/0/00
# 995  SA91515       0                   111                    1/0/00
#
#           State     Policy Type  Vehicle Class  Total Claim Amount GENDER  \
# ...

# %%
frames = [dataset1, dataset2, dataset3]
datasets = pd.concat(frames)
datasets
# Out:
#     Customer   Income  Monthly Premium Auto Number of Open Complaints  \
# 0    RB50392      0.0                1000.0                    1/0/00
# 1    QZ44356      0.0                  94.0                    1/0/00
# 2    AI49188  48767.0                 108.0                    1/0/00
# 3    WW63253      0.0                 106.0                    1/0/00
# 4    GA49547  36357.0                  68.0                    1/0/00
# ..       ...      ...                   ...                       ...
# 991  HV85198  63513.0                  70.0                    1/0/00
# 992  BS91566  58161.0                  68.0                    1/0/00
# 993  IL40123  83640.0                  70.0                    1/0/00
# 994  MY32149      0.0                  96.0                    1/0/00
# 995  SA91515      0.0                 111.0                    1/0/00
#
#           State     Policy Type  Vehicle Class  Total Claim Amount GENDER  \
# ...

# %%
datasets.select_dtypes(exclude=['object']).columns.tolist()
# Out:
# ['Income', 'Monthly Premium Auto', 'Total Claim Amount']

# %%
datasets.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['Customer',
#  'Number of Open Complaints',
#  'State',
#  'Policy Type',
#  'Vehicle Class',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value']

# %%
#Perform the data cleaning operations mentioned so far in class

# %%
datasets.drop('Education', axis = 1, inplace = True)
datasets.drop('Number of Open Complaints', axis = 1, inplace = True)

# %%
datasets
# Out:
#     Customer   Income  Monthly Premium Auto       State     Policy Type  \
# 0    RB50392      0.0                1000.0  Washington   Personal Auto
# 1    QZ44356      0.0                  94.0     Arizona   Personal Auto
# 2    AI49188  48767.0                 108.0      Nevada   Personal Auto
# 3    WW63253      0.0                 106.0  California  Corporate Auto
# 4    GA49547  36357.0                  68.0  Washington   Personal Auto
# ..       ...      ...                   ...         ...             ...
# 991  HV85198  63513.0                  70.0     Arizona   Personal Auto
# 992  BS91566  58161.0                  68.0     Arizona  Corporate Auto
# 993  IL40123  83640.0                  70.0      Nevada  Corporate Auto
# 994  MY32149      0.0                  96.0  California   Personal Auto
# 995  SA91515      0.0                 111.0  California   Personal Auto
#
#      Vehicle Class  Total Claim Amount GENDER Customer Lifetime Value
# ...

# %%
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type

# %%
datasets['Customer Lifetime Value'] = datasets['Customer Lifetime Value'].apply(lambda x : x*100)

# %%
datasets ['Customer Lifetime Value'] = datasets['Customer Lifetime Value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [160], in <cell line: 1>()
# ----> 1 datasets ['Customer Lifetime Value'] = datasets['Customer Lifetime Value'].astype('int')
#
# File C:\New folder\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File C:\New folder\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# Check for duplicate rows in the data and remove if any

# %%
datasets.drop_duplicates (inplace=True, ignore_index=False)

# %%
datasets
# Out:
#     Customer   Income  Monthly Premium Auto       State     Policy Type  \
# 0    RB50392      0.0                1000.0  Washington   Personal Auto
# 1    QZ44356      0.0                  94.0     Arizona   Personal Auto
# 2    AI49188  48767.0                 108.0      Nevada   Personal Auto
# 3    WW63253      0.0                 106.0  California  Corporate Auto
# 4    GA49547  36357.0                  68.0  Washington   Personal Auto
# ..       ...      ...                   ...         ...             ...
# 991  HV85198  63513.0                  70.0     Arizona   Personal Auto
# 992  BS91566  58161.0                  68.0     Arizona  Corporate Auto
# 993  IL40123  83640.0                  70.0      Nevada  Corporate Auto
# 994  MY32149      0.0                  96.0  California   Personal Auto
# 995  SA91515      0.0                 111.0  California   Personal Auto
#
#      Vehicle Class  Total Claim Amount GENDER  \
# 0    Four-Door Car            2.704934    NaN
# ...
